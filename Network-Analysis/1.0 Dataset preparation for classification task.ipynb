# %%
import pandas as pd
import matplotlib.pyplot as plt

import itertools
import networkx as nx

# %% [markdown]
# ## Dataset "porti_20_22" - utenti contro

# %%
df_c = pd.read_csv("../../data_collection/data/porti_18_22.csv", sep=',')

# %%
df_c.shape
# Out:
# (53424, 16)

# %%
df_c = df_c.drop(df_c[df_c.Language != "it"].index)
df_c['tweet_label'] = 0

# %%
contro = []
for i in df_c.index:
    if df_c['User'][i] not in contro:
        contro.append(df_c['User'][i])

# %% [markdown]
# ## Dataset scapp_20_22 - utenti pro

# %%
df_p = pd.read_csv("../../data_collection/data/scapp_18_22.csv", sep=',')

# %%
df_p = df_p.drop(df_p[df_p.Language != "it"].index)
df_p['tweet_label'] = 1

# %%
df_p.shape
# Out:
# (67054, 17)

# %%
pro = []
for i in df_p.index:
    if df_p['User'][i] not in pro:
        pro.append(df_p['User'][i])

# %%
df_conc2= pd.concat([df_p, df_c])

# %%
df_conc2.to_csv("../../data_collection/data/dataset_conc_iniziale.csv", index=False)

# %% [markdown]
# ## Dataset tweet generali

# %%
df = pd.read_csv("../../data_collection/data/df_def.csv", sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131963 entries, 0 to 131962
# Data columns (total 20 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   User             131963 non-null  object
#  1   verified         131963 non-null  bool
#  2   Date_Created     131963 non-null  object
#  3   Follows_Count    131963 non-null  int64
#  4   Friends_Count    131963 non-null  int64
#  5   Retweet_Count    131963 non-null  int64
#  6   Language         131963 non-null  object
#  7   Number_of_Likes  131963 non-null  int64
#  8   Source_of_Tweet  131963 non-null  object
#  9   Tweet_Id         131963 non-null  int64
#  10  Tweet            131963 non-null  object
#  11  Hashtags         9366 non-null    object
#  12  Conversation_Id  131963 non-null  int64
#  13  In_reply_To      128539 non-null  object
#  14  Coordinates      2813 non-null    object
#  15  Place            2813 non-null    object
#  16  Data_Tweet       131963 non-null  object
#  17  Month            131963 non-null  int64
#  18  Year             131963 non-null  int64
#  19  Year_Month       131963 non-null  object
# dtypes: bool(1), int64(8), object(11)
# memory usage: 19.3+ MB

# %%
df = df.drop(df[df.Language != "it"].index)

# %%
df.shape
# Out:
# (131877, 20)

# %%
df['tweet_label'] = -100

# %%
df['Hashtags'].fillna("None", inplace=True)
df['In_reply_To'].fillna(df['User'], inplace=True)

# %%
df['mention'] = (df.Tweet.str.findall(r'(?<![@\w])@(\w{1,25})').apply(','.join))

# %% [markdown]
# ## Tweet context
#
# ### Ucrain

# %%
import re
import numpy as np

ukr = df[df['Tweet'].str.contains(r'ucrain', flags = re.IGNORECASE)]

ukr.reset_index(inplace = True)

print("\n dataset shape: ", ukr.shape)

print("\n Number of unique conversation ID: ", ukr['Conversation_Id'].nunique())

#New column in orginal dataframe
df['ukr'] = np.where(df['Tweet'].str.contains(r'ucrain', case=False, na=False, flags = re.IGNORECASE), 1, 0)
# Out:
#  dataset shape:  (808, 23)
#
#  Number of unique conversation ID:  132

# %% [markdown]
# ### ucraina/o & immigra-zione immigra-to/ta/te/ti

# %%
ukr_imm = ukr[ukr['Tweet'].str.contains(r'immigra', flags = re.IGNORECASE)]

ukr_imm.reset_index(inplace = True)

print("\n dataset shape: ", ukr_imm.shape)
print("\n Number of unique conversation ID: ", ukr_imm['Conversation_Id'].nunique())


#New column
df['imm'] = np.where(df['Tweet'].str.contains(r'immigra', flags = re.IGNORECASE), 1, 0)
# Out:
#  dataset shape:  (32, 24)
#
#  Number of unique conversation ID:  19

# %% [markdown]
# ### ucraina/o & profugo/a/hi/he

# %%
ukr_pro = ukr[ukr['Tweet'].str.contains(r'profug', flags = re.IGNORECASE)]

ukr_pro.reset_index(inplace = True)

print("\n dataset shape: ", ukr_pro.shape)
print("\n Number of unique conversation ID: ", ukr_pro['Conversation_Id'].nunique())


#New column
df['prof'] = np.where(df['Tweet'].str.contains(r'profug', flags = re.IGNORECASE), 1, 0)
# Out:
#  dataset shape:  (160, 24)
#
#  Number of unique conversation ID:  54

# %% [markdown]
# ### ucraina/o & migrant/e/i

# %%
ukr_mig = ukr[ukr['Tweet'].str.contains(r'migrant', flags = re.IGNORECASE)]
ukr_mig.reset_index(inplace = True)

print("\n dataset shape: ", ukr_mig.shape)
print("\n Number of unique conversation ID: ", ukr_mig['Conversation_Id'].nunique())

#new column 
df['migr'] = np.where(df['Tweet'].str.contains(r'migrant', flags = re.IGNORECASE), 1, 0)
# Out:
#  dataset shape:  (69, 24)
#
#  Number of unique conversation ID:  38

# %% [markdown]
# ### ucraina/o & profughi veri

# %%
ukr_pv = ukr[ukr['Tweet'].str.contains(r"profughi veri", flags = re.IGNORECASE)]
ukr_pv.reset_index(inplace = True)

print("\n dataset shape: ", ukr_pv.shape)
print("\n Number of unique conversation ID: ", ukr_pv['Conversation_Id'].nunique())

#new column 
df['prof_v'] = np.where(df['Tweet'].str.contains(r'profughi veri', flags = re.IGNORECASE), 1, 0)
# Out:
#  dataset shape:  (13, 24)
#
#  Number of unique conversation ID:  8

# %%
df[df['User']=="matteosalvinimi"]
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 131593  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131600  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131602  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131610  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495096
# 131635  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131639  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131674  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131685  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131700  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131704  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131714  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131715  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131717  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131719  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131724  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131728  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131731  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131735  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131740  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131745  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131749  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495096
# 131761  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131772  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131781  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495096
# 131782  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131785  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131786  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131793  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131795  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131799  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495096
# 131811  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131816  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131819  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131824  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131830  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131844  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131853  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131855  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131857  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131860  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131862  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131869  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131875  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131908  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495096
# 131925  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131937  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495096
# 131940  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131943  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
# 131958  matteosalvinimi      True  2011-03-23 10:32:56+00:00        1495095
#
#         Friends_Count  Retweet_Count Language  Number_of_Likes  \
# 131593           2007            582       it             2574
# 131600           2007            354       it             1350
# 131602           2007            101       it              541
# 131610           2007            538       it             2142
# 131635           2007            289       it              898
# 131639           2007            618       it             1673
# 131674           2007            176       it             1212
# 131685           2007            103       it             1749
# 131700           2007            216       it             1129
# 131704           2007            241       it             1553
# 131714           2007            382       it             2213
# 131715           2007            355       it             1194
# 131717           2007            130       it              944
# 131719           2007            275       it             3076
# 131724           2007            301       it             1526
# 131728           2007            557       it             3621
# 131731           2007            399       it             2511
# 131735           2007             77       it              517
# 131740           2007            255       it             1140
# 131745           2007            830       it             4258
# 131749           2007            498       it             1997
# 131761           2007            465       it             2916
# 131772           2007            309       it             2522
# 131781           2007            417       it             2210
# 131860       Twitter Web App  1481049320849874947  ...     1  2022
# 131862   Twitter for Android  1479522328237289473  ...     1  2022
# 131869    Twitter for iPhone  1490436401271394308  ...     2  2022
# 131875    Twitter for iPhone  1507284421346574386  ...     3  2022
# 131908    Twitter for iPhone  1525777339594031104  ...     5  2022
# 131925    Twitter for iPhone  1545501952779423749  ...     7  2022
# 131937    Twitter for iPhone  1563955335303421953  ...     8  2022
# 131940  Twitter Media Studio  1562388760603820033  ...     8  2022
# 131943    Twitter for iPhone  1554877634709970944  ...     8  2022
# 131958       Twitter Web App  1554787555438206977  ...     8  2022
#
#         Year_Month tweet_label         mention ukr imm  prof  migr prof_v
# 131593      2020-9        -100                   0   0     0     0      0
# 131600      2020-9        -100                   0   1     0     0      0
# 131602      2020-9        -100                   0   0     0     0      0
# 131610      2020-9        -100                   0   0     0     0      0
# 131635     2020-10        -100                   0   0     0     0      0
# 131639     2020-11        -100                   0   0     0     0      0
# 131674      2021-2        -100                   0   0     0     0      0
# 131685      2021-3        -100                   0   0     0     0      0
# 131700      2021-4        -100        Corriere   0   0     0     0      0
# 131704      2021-4        -100                   0   0     0     0      0
# 131714      2021-4        -100                   0   0     0     0      0
# 131715      2021-4        -100                   0   0     0     0      0
# 131717      2021-4        -100                   0   0     0     0      0
# 131719      2021-4        -100                   0   0     0     0      0
# 131724      2021-5        -100                   0   0     0     0      0
# 131728      2021-5        -100                   0   1     0     0      0
# 131731      2021-5        -100                   0   0     0     0      0
# 131735      2021-5        -100                   0   0     0     0      0
# 131740      2021-5        -100                   0   0     0     0      0
# 131745      2021-5        -100                   0   0     0     0      0
# 131749      2021-5        -100                   0   0     0     0      0
# 131761      2021-6        -100                   0   0     0     0      0
# 131772      2021-7        -100                   0   0     0     0      0
# 131781      2021-7        -100                   0   1     0     0      0
# 131782      2021-8        -100                   0   1     0     0      0
# 131785      2021-8        -100                   0   1     0     0      0
# 131786      2021-8        -100                   0   0     0     0      0
# 131793      2021-8        -100                   0   0     0     0      0
# 131795      2021-8        -100                   0   0     0     0      0
# 131799      2021-8        -100                   0   0     0     0      0
# 131811     2021-10        -100                   0   1     0     0      0
# 131816     2021-10        -100                   0   0     0     0      0
# 131819     2021-10        -100  RaiPortaaPorta   0   0     0     0      0
# 131824     2021-11        -100                   0   0     0     0      0
# 131830     2021-11        -100                   0   1     0     0      0
# 131844     2021-12        -100                   0   0     0     0      0
# 131853     2021-12        -100                   0   0     0     0      0
# 131855      2022-1        -100                   0   0     0     0      0
# 131857      2022-1        -100                   0   1     0     0      0
# 131860      2022-1        -100                   0   1     0     0      0
# 131862      2022-1        -100                   0   0     0     0      0
# 131869      2022-2        -100                   0   0     0     1      0
# 131875      2022-3        -100                   0   0     1     0      1
# 131908      2022-5        -100                   0   0     0     0      0
# 131925      2022-7        -100                   0   0     0     0      0
# 131937      2022-8        -100                   0   0     0     0      0
# 131940      2022-8        -100                   0   0     0     0      0
# 131943      2022-8        -100                   0   1     0     0      0
# 131958      2022-8        -100                   0   0     0     0      0
#
# [49 rows x 27 columns]

# %%
df.to_csv("../../data_collection/data/dataset_all.csv", index=False)
