# %%
import tweepy
import configparser
import pandas as pd
import snscrape.modules.twitter as sntwitter
import time
import itertools

# %%
def tweet_scraper(query, n_tweet):
    
    attributes_container = []
    max_tweet = n_tweet
    
    #faccio scraping e uso enumerate per tenere conto dei tweet
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):

        if i>max_tweet:
            break
            
        attributes_container.append([tweet.user.username,
                                     tweet.user.verified,
                                     tweet.user.created,
                                     tweet.user.followersCount, #persone che seguono l'utente
                                     tweet.user.friendsCount, #persone seguite dall'utente
                                     tweet.retweetCount,
                                     tweet.lang,
                                     tweet.date,
                                     tweet.likeCount,
                                     tweet.sourceLabel,
                                     tweet.id,
                                     tweet.content,
                                     tweet.hashtags,
                                     tweet.conversationId,
                                     tweet.inReplyToUser,
                                     tweet.coordinates,
                                     tweet.place])
        
    #Creo df
    return pd.DataFrame(attributes_container, columns=["User",
                                                       "verified",
                                                       "Date_Created",
                                                       "Follows_Count",
                                                       "Friends_Count",
                                                       "Retweet_Count",
                                                       "Language",
                                                       "Date_Tweet",
                                                       "Number_of_Likes",
                                                       "Source_of_Tweet",
                                                       "Tweet_Id",
                                                       "Tweet",
                                                       "Hashtags",
                                                       "Conversation_Id",
                                                       "In_reply_To",
                                                       "Coordinates",
                                                       "Place"])

# %% [markdown]
# ## Ricerca hashtag singoli

# %% [markdown]
# ### rifugiato/rifugiati

# %%
rif_20_22 = tweet_scraper('(#rifugiati OR #rifugiato) since:2020-09-01 until:2022-09-01', 500000)

# %%
rif_20_22

# %%
#rif_20_22.to_csv("rif_20_22.csv", sep=",", index=False)

# %% [markdown]
# ### migrante/migranti

# %%
migr_20_22 = tweet_scraper('(#migranti OR #migrante) since:2020-09-01 until:2022-09-01', 500000)

# %%
migr_20_22

# %%
#migr_20_22.to_csv("migr_20_22.csv", sep=",", index=False)

# %% [markdown]
# ## profugo/profughi

# %%
prof_20_22 = tweet_scraper('(#profughi OR #profugo) since:2020-09-01 until:2022-09-01', 500000)

# %%
prof_20_22

# %%
#prof_20_22.to_csv("prof_20_22.csv", sep=",", index=False)

# %% [markdown]
# ## Creo primo Dataset

# %%
migranti = pd.read_csv("./data/migr_20_22.csv")
profughi = pd.read_csv("./data/prof_20_22.csv")
rifugiati = pd.read_csv("./data/rif_20_22.csv")

# %%
df = pd.concat([migranti, profughi, rifugiati])

# %%
df.reset_index(inplace=True)
df
# Out:
#        index             User  verified               Date_Created  \
# 0          0       HermanosVE     False  2021-04-10 18:43:26+00:00
# 1          1  MediasetTgcom24      True  2011-07-08 13:12:20+00:00
# 2          2       Satiraptus     False  2016-01-13 13:08:35+00:00
# 3          3     FaroDigital_     False  2014-03-04 15:16:17+00:00
# 4          4      CurulPuebla     False  2019-08-12 02:44:41+00:00
# ...      ...              ...       ...                        ...
# 74446   5638      PasseriniTn     False  2013-02-11 13:18:07+00:00
# 74447   5639         SteGiolo     False  2016-07-05 12:10:45+00:00
# 74448   5640        SmvRomano     False  2013-10-03 11:42:08+00:00
# 74449   5641    AncoraFischia     False  2012-12-16 18:57:36+00:00
# 74450   5642    CaritasAncona     False  2018-06-27 08:14:43+00:00
#
#        Follows_Count  Friends_Count  Retweet_Count Language  \
# 0                242             53              3       es
# 1            1411371            958              4       it
# 2               9943           4610              1       it
# 3               2553            250              0       es
# 4               1396            138              2       es
# ...              ...            ...            ...      ...
# 74446            265           1142              0       it
# 74447             48            332              0       it
# 74448           1002           1628              1       it
# 74449           6759           2514              1       it
# 74450            255            344              0       it
#
#                       Date_Tweet  Number_of_Likes      Source_of_Tweet  \
# 0      2022-08-31 23:34:41+00:00                6  Twitter for Android
# 1      2022-08-31 23:10:00+00:00               21     Social Mediaset
# 2      2022-08-31 22:00:06+00:00               21  Twitter for Android
# 3      2022-08-31 21:18:48+00:00                0   Twitter for iPhone
# 4      2022-08-31 20:57:10+00:00                2  Twitter for Android
# ...                          ...              ...                  ...
# 74446  2020-09-01 11:47:52+00:00                0      Twitter Web App
# 74447  2020-09-01 11:24:57+00:00                0      Twitter Web App
# 74448  2020-09-01 11:06:16+00:00                3      Twitter Web App
# 74449  2020-09-01 08:03:48+00:00                1  Twitter for Android
# 74450  2020-09-01 07:27:17+00:00                5  Twitter for Android
#
#                   Tweet_Id                                              Tweet  \
# 0      1565120923044380673  Te invitamos a un #LIVE con Marcos Garzón, coo...
# 1      1565114713586950145  Migranti, entro 24 ore oltre mille via da Lamp...
# 2      1565097120994131969  #Calabria. #Briatore salva 100 #migranti col s...
# 3      1565086727819124737  🚶🏽|| ¿Conoces algún #migrante que llegó a #Pue...
# 4      1565081284539518979  🚘  🛃 || #Puebla da la bienvenida a los connaci...
# ...                    ...                                                ...
# 74446  1300762294956294144  Cinque anni fa la #Germania accolse un #milion...
# 74447  1300756525754056704  Cinque anni fa la Germania accolse un milione ...
# 74448  1300751824182562816  📢La presenza di #migranti nelle strutture di a...
# 74449  1300705904938102785  #Banksy ha finanziato una nave per salvare i #...
# 74450  1300696714677026817  #SfollaticomeGesù #WDMR2020\nIl tema scelto da...
#
#                                                 Hashtags      Conversation_Id  \
# 0      ['LIVE', '1SEP', 'Chile', 'venezolanos', 'migr...  1565120923044380673
# 1                              ['lampedusa', 'migranti']  1565114713586950145
# 2      ['Calabria', 'Briatore', 'migranti', 'Mediterr...  1565097120994131969
# 3      ['migrante', 'Puebla', 'FaroDigital', 'Puebla'...  1565086727819124737
# 4           ['Puebla', 'Migrante', 'Poblano', 'Viajero']  1565081284539518979
# ...                                                  ...                  ...
# 74446      ['Germania', 'milione', 'rifugiati', 'Siria']  1300762294956294144
# 74447  ['ANGELAMERKEL', 'GERMANIA', 'GUERRAINSIRIA', ...  1300756525754056704
# 74448  ['migranti', 'rifugiati', 'Asilo', 'restiamoUm...  1300751824182562816
# 74449                            ['Banksy', 'rifugiati']  1300705904938102785
# 74450  ['SfollaticomeGesù', 'WDMR2020', 'migrante', '...  1300696714677026817
#
#       In_reply_To Coordinates Place
# 0             NaN         NaN   NaN
# 1             NaN         NaN   NaN
# 2             NaN         NaN   NaN
# 3             NaN         NaN   NaN
# 4             NaN         NaN   NaN
# ...           ...         ...   ...
# 74446         NaN         NaN   NaN
# 74447         NaN         NaN   NaN
# 74448         NaN         NaN   NaN
# 74449         NaN         NaN   NaN
# 74450         NaN         NaN   NaN
#
# [74451 rows x 18 columns]

# %%
del(df['index'])
df
# Out:
#                   User  verified               Date_Created  Follows_Count  \
# 0           HermanosVE     False  2021-04-10 18:43:26+00:00            242
# 1      MediasetTgcom24      True  2011-07-08 13:12:20+00:00        1411371
# 2           Satiraptus     False  2016-01-13 13:08:35+00:00           9943
# 3         FaroDigital_     False  2014-03-04 15:16:17+00:00           2553
# 4          CurulPuebla     False  2019-08-12 02:44:41+00:00           1396
# ...                ...       ...                        ...            ...
# 74446      PasseriniTn     False  2013-02-11 13:18:07+00:00            265
# 74447         SteGiolo     False  2016-07-05 12:10:45+00:00             48
# 74448        SmvRomano     False  2013-10-03 11:42:08+00:00           1002
# 74449    AncoraFischia     False  2012-12-16 18:57:36+00:00           6759
# 74450    CaritasAncona     False  2018-06-27 08:14:43+00:00            255
#
#        Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                 53              3       es  2022-08-31 23:34:41+00:00
# 1                958              4       it  2022-08-31 23:10:00+00:00
# 2               4610              1       it  2022-08-31 22:00:06+00:00
# 3                250              0       es  2022-08-31 21:18:48+00:00
# 4                138              2       es  2022-08-31 20:57:10+00:00
# ...              ...            ...      ...                        ...
# 74446           1142              0       it  2020-09-01 11:47:52+00:00
# 74447            332              0       it  2020-09-01 11:24:57+00:00
# 74448           1628              1       it  2020-09-01 11:06:16+00:00
# 74449           2514              1       it  2020-09-01 08:03:48+00:00
# 74450            344              0       it  2020-09-01 07:27:17+00:00
#
#        Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 0                    6  Twitter for Android  1565120923044380673
# 1                   21     Social Mediaset   1565114713586950145
# 2                   21  Twitter for Android  1565097120994131969
# 3                    0   Twitter for iPhone  1565086727819124737
# 4                    2  Twitter for Android  1565081284539518979
# ...                ...                  ...                  ...
# 74446                0      Twitter Web App  1300762294956294144
# 74447                0      Twitter Web App  1300756525754056704
# 74448                3      Twitter Web App  1300751824182562816
# 74449                1  Twitter for Android  1300705904938102785
# 74450                5  Twitter for Android  1300696714677026817
#
#                                                    Tweet  \
# 0      Te invitamos a un #LIVE con Marcos Garzón, coo...
# 1      Migranti, entro 24 ore oltre mille via da Lamp...
# 2      #Calabria. #Briatore salva 100 #migranti col s...
# 3      🚶🏽|| ¿Conoces algún #migrante que llegó a #Pue...
# 4      🚘  🛃 || #Puebla da la bienvenida a los connaci...
# ...                                                  ...
# 74446  Cinque anni fa la #Germania accolse un #milion...
# 74447  Cinque anni fa la Germania accolse un milione ...
# 74448  📢La presenza di #migranti nelle strutture di a...
# 74449  #Banksy ha finanziato una nave per salvare i #...
# 74450  #SfollaticomeGesù #WDMR2020\nIl tema scelto da...
#
#                                                 Hashtags      Conversation_Id  \
# 0      ['LIVE', '1SEP', 'Chile', 'venezolanos', 'migr...  1565120923044380673
# 1                              ['lampedusa', 'migranti']  1565114713586950145
# 2      ['Calabria', 'Briatore', 'migranti', 'Mediterr...  1565097120994131969
# 3      ['migrante', 'Puebla', 'FaroDigital', 'Puebla'...  1565086727819124737
# 4           ['Puebla', 'Migrante', 'Poblano', 'Viajero']  1565081284539518979
# ...                                                  ...                  ...
# 74446      ['Germania', 'milione', 'rifugiati', 'Siria']  1300762294956294144
# 74447  ['ANGELAMERKEL', 'GERMANIA', 'GUERRAINSIRIA', ...  1300756525754056704
# 74448  ['migranti', 'rifugiati', 'Asilo', 'restiamoUm...  1300751824182562816
# 74449                            ['Banksy', 'rifugiati']  1300705904938102785
# 74450  ['SfollaticomeGesù', 'WDMR2020', 'migrante', '...  1300696714677026817
#
#       In_reply_To Coordinates Place
# 0             NaN         NaN   NaN
# 1             NaN         NaN   NaN
# 2             NaN         NaN   NaN
# 3             NaN         NaN   NaN
# 4             NaN         NaN   NaN
# ...           ...         ...   ...
# 74446         NaN         NaN   NaN
# 74447         NaN         NaN   NaN
# 74448         NaN         NaN   NaN
# 74449         NaN         NaN   NaN
# 74450         NaN         NaN   NaN
#
# [74451 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74451 entries, 0 to 74450
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User             74451 non-null  object
#  1   verified         74451 non-null  bool
#  2   Date_Created     74451 non-null  object
#  3   Follows_Count    74451 non-null  int64
#  4   Friends_Count    74451 non-null  int64
#  5   Retweet_Count    74451 non-null  int64
#  6   Language         74451 non-null  object
#  7   Date_Tweet       74451 non-null  object
#  8   Number_of_Likes  74451 non-null  int64
#  9   Source_of_Tweet  74451 non-null  object
#  10  Tweet_Id         74451 non-null  int64
#  11  Tweet            74451 non-null  object
#  12  Hashtags         74434 non-null  object
#  13  Conversation_Id  74451 non-null  int64
#  14  In_reply_To      9369 non-null   object
#  15  Coordinates      2029 non-null   object
#  16  Place            2029 non-null   object
# dtypes: bool(1), int64(6), object(10)
# memory usage: 9.2+ MB

# %%
df["User"].nunique()
# Out:
# 13575

# %%
df['Conversation_Id'].nunique()
# Out:
# 69580

# %%
df['Tweet'].nunique()
# Out:
# 71735

# %% [markdown]
# Elimino tweet doppi soggeti a spam

# %%
df.drop_duplicates(subset=['Tweet', 'User'], inplace=True)

# %%
df["In_reply_To"] = df["In_reply_To"].str.replace("https://twitter.com/", "")
# Out:
# C:\Users\lpall\AppData\Local\Temp\ipykernel_8876\3522921684.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["In_reply_To"] = df["In_reply_To"].str.replace("https://twitter.com/", "")

# %%
df["In_reply_To"][10:20]
# Out:
# 10              NaN
# 11              NaN
# 12    chiuderetutto
# 13              NaN
# 14              NaN
# 15              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN
# Name: In_reply_To, dtype: object

# %% [markdown]
# Voglio prendere solo i tweet che sono in risposta a qualcuno ma non cancellando quelli source. Da verificare se il conversation ID del source esiste.

# %%
df = df[df.duplicated(subset=['Conversation_Id'], keep=False)]

# %%
df
# Out:
#                   User  verified               Date_Created  Follows_Count  \
# 32     DorAntifascista     False  2018-06-22 08:12:10+00:00           2074
# 34          maurobiani     False  2007-08-06 20:19:05+00:00          79692
# 40        EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 41        EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 91           GerriLiu5     False  2018-08-28 21:10:41+00:00            353
# ...                ...       ...                        ...            ...
# 74266           Brazz0     False  2011-03-11 16:34:52+00:00            639
# 74343           Brazz0     False  2011-03-11 16:34:52+00:00            639
# 74351           Brazz0     False  2011-03-11 16:34:52+00:00            639
# 74354         jeperego     False  2013-12-15 21:55:05+00:00          11476
# 74403  Kwizera06428241     False  2018-07-09 07:37:37+00:00           1199
#
#        Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 32              2138              0       it  2022-08-31 15:04:03+00:00
# 34              4196            249       it  2022-08-31 14:43:58+00:00
# 40              9958              0       es  2022-08-31 12:53:16+00:00
# 41              9958              6       es  2022-08-31 12:51:54+00:00
# 91               292              0      qme  2022-08-30 16:33:55+00:00
# ...              ...            ...      ...                        ...
# 74266           2260              0       it  2020-09-27 10:25:10+00:00
# 74343           2260              0       it  2020-09-18 09:30:13+00:00
# 74351           2260              0       it  2020-09-16 08:58:41+00:00
# 74354           1964             91       it  2020-09-15 15:24:52+00:00
# 74403            350              0       it  2020-09-09 11:11:06+00:00
#
#        Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 32                   0  Twitter for Android  1564992420714012672
# 34                 989      Twitter Web App  1564987364946186242
# 40                   1   Twitter for iPhone  1564959504386740225
# 41                  10   Twitter for iPhone  1564959162693558273
# 91                   0  Twitter for Android  1564652646505619460
# ...                ...                  ...                  ...
# 74266                0      Twitter Web App  1310163564393529344
# 74343                1      Twitter Web App  1306888245486256128
# 74351                0      Twitter Web App  1306155533855055872
# 74354              330      Twitter Web App  1305890333398650880
# 74403                0  Twitter for Android  1303652142503387137
#
#                                                    Tweet  \
# 32     @maurobiani @repubblica Due cuori e una Campag...
# 34     #persone #migranti #salvini #meloni #CampagnaE...
# 40     Estas mil 93 denuncias contra menores de edad ...
# 41     En #México, al menos mil 93 niñas, niños y ado...
# 91     @bartolopietro1 @repubblica #migranti #impegno...
# ...                                                  ...
# 74266  "Lo sport è il modo migliore che ho trovato pe...
# 74343  "È come aprire una ferita per vederla guarire ...
# 74351  Titolo a parte (sic), la determinazione, la co...
# 74354  La #Germania accoglierà 1553 #rifugiati dalle ...
# 74403  @Capobianco2005C @Avvenire_Nei @nelloscavo Dov...
#
#                                                 Hashtags      Conversation_Id  \
# 32                    ['persone', 'migranti', 'Matrice']  1564987364946186242
# 34     ['persone', 'migranti', 'salvini', 'meloni', '...  1564987364946186242
# 40                                          ['migrante']  1564959162693558273
# 41                    ['México', 'víctimas', 'migrante']  1564959162693558273
# 91                  ['migranti', 'impegno', 'Lampedusa']  1564563868705329155
# ...                                                  ...                  ...
# 74266                                      ['Rifugiati']  1274268174272299008
# 74343                           ['Somalia', 'rifugiati']  1274268174272299008
# 74351                                      ['rifugiati']  1274268174272299008
# 74354                          ['Germania', 'rifugiati']  1305890333398650880
# 74403                                      ['rifugiato']  1303605323589210118
#
#            In_reply_To Coordinates Place
# 32          maurobiani         NaN   NaN
# 34                 NaN         NaN   NaN
# 40        EuniceRendon         NaN   NaN
# 41                 NaN         NaN   NaN
# 91      bartolopietro1         NaN   NaN
# ...                ...         ...   ...
# 74266           Brazz0         NaN   NaN
# 74343           Brazz0         NaN   NaN
# 74351           Brazz0         NaN   NaN
# 74354              NaN         NaN   NaN
# 74403  Capobianco2005C         NaN   NaN
#
# [4350 rows x 17 columns]

# %%
df['Conversation_Id'].nunique()
# Out:
# 1743

# %%
df['User'].nunique()
# Out:
# 998

# %%
df1 = df.drop_duplicates(subset='Conversation_Id')
df1.Conversation_Id
# Out:
# 32       1564987364946186242
# 40       1564959162693558273
# 91       1564563868705329155
# 116      1564559016759533569
# 165      1563958254744518656
#                 ...
# 73036    1384145500467724295
# 73120    1375009994630909958
# 73730    1347089841641512960
# 73985    1328727284388401153
# 74006    1327172894816940033
# Name: Conversation_Id, Length: 1743, dtype: int64

# %% [markdown]
# ### Recupero tutte le conversazioni che riguardano i tweet trovati precedentemente

# %%
#inizializzo lista
attributes_container = []
max_tweet = 100000

for j, id in enumerate(df1.Conversation_Id):
#faccio scraping e uso enumerate per tenere conto dei tweet
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('conversation_id:' + str(id) +' (filter:safe OR -filter:safe)').get_items()):
        #print(tweet.content)
        #print('')
        if i>max_tweet:
            break
        attributes_container.append([tweet.user.username,
                                 tweet.user.verified,
                                 tweet.user.created,
                                 tweet.user.followersCount, #persone che seguono l'utente
                                 tweet.user.friendsCount, #persone seguite dall'utente
                                 tweet.retweetCount,
                                 tweet.lang,
                                 tweet.date,
                                 tweet.likeCount,
                                 tweet.sourceLabel,
                                 tweet.id,
                                 tweet.content,
                                 tweet.hashtags,
                                 tweet.conversationId,
                                 tweet.inReplyToUser,
                                 tweet.coordinates,
                                 tweet.place])
    
#Creo df
conversation_20_22 = pd.DataFrame(attributes_container, columns=["User",
                                                "verified",
                                                "Date_Created",
                                                "Follows_Count",
                                                "Friends_Count",
                                                "Retweet_Count",
                                                "Language",
                                                "Date_Tweet",
                                                "Number_of_Likes",
                                                "Source_of_Tweet",
                                                "Tweet_Id",
                                                "Tweet",
                                                "Hashtags",
                                                "Conversation_Id",
                                                "In_reply_To",
                                                "Coordinates",
                                                "Place"])

# %%
conversation_20_22

# %%
conversation_20_22.to_csv("./data/conversation_20_22.csv", sep=",", index=False)

# %%
conversazioni = pd.read_csv("./data/conversation_20_22.csv")

# %% [markdown]
# ## Creo secondo dataset con tutte le conversazioni

# %%
df = pd.concat([df, conversazioni])

# %%
df
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 32      DorAntifascista     False  2018-06-22 08:12:10+00:00           2074
# 34           maurobiani     False  2007-08-06 20:19:05+00:00          79692
# 40         EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 41         EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 91            GerriLiu5     False  2018-08-28 21:10:41+00:00            353
# ...                 ...       ...                        ...            ...
# 360743         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 360744       CosmolukaG     False  2012-05-30 14:39:50+00:00            415
# 360745        cino_1969     False  2012-05-16 11:27:04+00:00           1961
# 360746         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 360747         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
#
#         Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 32               2138              0       it  2022-08-31 15:04:03+00:00
# 34               4196            249       it  2022-08-31 14:43:58+00:00
# 40               9958              0       es  2022-08-31 12:53:16+00:00
# 41               9958              6       es  2022-08-31 12:51:54+00:00
# 91                292              0      qme  2022-08-30 16:33:55+00:00
# ...               ...            ...      ...                        ...
# 360743           3213              0       it  2020-11-13 09:26:07+00:00
# 360744           1534              0       it  2020-11-13 09:19:49+00:00
# 360745           1837              0      qme  2020-11-13 09:00:48+00:00
# 360746           3213             27       it  2020-11-13 08:59:38+00:00
# 360747           3213             17       it  2020-11-13 08:57:07+00:00
#
#         Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 32                    0  Twitter for Android  1564992420714012672
# 34                  989      Twitter Web App  1564987364946186242
# 40                    1   Twitter for iPhone  1564959504386740225
# 41                   10   Twitter for iPhone  1564959162693558273
# 91                    0  Twitter for Android  1564652646505619460
# ...                 ...                  ...                  ...
# 360743                6      Twitter Web App  1327180935738109953
# 360744               12  Twitter for Android  1327179349016064002
# 360745                1  Twitter for Android  1327174565135593472
# 360746               75      Twitter Web App  1327174271328718851
# 360747               79      Twitter Web App  1327173639293300737
#
#                                                     Tweet  \
# 32      @maurobiani @repubblica Due cuori e una Campag...
# 34      #persone #migranti #salvini #meloni #CampagnaE...
# 40      Estas mil 93 denuncias contra menores de edad ...
# 41      En #México, al menos mil 93 niñas, niños y ado...
# 91      @bartolopietro1 @repubblica #migranti #impegno...
# ...                                                   ...
# 360743                      @gianlufratta la ringrazio...
# 360744  @SMaurizi Menomale che esistono ancora persone...
# 360745                  @SMaurizi https://t.co/JcygYTGuvi
# 360746  3. non potrò mai dimenticare #cablo come quest...
# 360747  2. ho passato gli ultimi 10 anni a leggere i f...
#
#                                                  Hashtags  \
# 32                     ['persone', 'migranti', 'Matrice']
# 34      ['persone', 'migranti', 'salvini', 'meloni', '...
# 40                                           ['migrante']
# 41                     ['México', 'víctimas', 'migrante']
# 91                   ['migranti', 'impegno', 'Lampedusa']
# ...                                                   ...
# 360743                                                NaN
# 360744                                                NaN
# 360745                                                NaN
# 360746                            ['cablo', 'GuerraIraq']
# 360747           ['Afghanistan', 'Iraq', 'cablo', 'Iraq']
#
#             Conversation_Id                     In_reply_To Coordinates Place
# 32      1564987364946186242                      maurobiani         NaN   NaN
# 34      1564987364946186242                             NaN         NaN   NaN
# 40      1564959162693558273                    EuniceRendon         NaN   NaN
# 41      1564959162693558273                             NaN         NaN   NaN
# 91      1564563868705329155                  bartolopietro1         NaN   NaN
# ...                     ...                             ...         ...   ...
# 360743  1327172894816940033  https://twitter.com/CosmolukaG         NaN   NaN
# 360744  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
# 360745  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
# 360746  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
# 360747  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
#
# [365098 rows x 17 columns]

# %%
df.reset_index(inplace=True)
del(df['index'])
df
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 0       DorAntifascista     False  2018-06-22 08:12:10+00:00           2074
# 1            maurobiani     False  2007-08-06 20:19:05+00:00          79692
# 2          EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 3          EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 4             GerriLiu5     False  2018-08-28 21:10:41+00:00            353
# ...                 ...       ...                        ...            ...
# 365093         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 365094       CosmolukaG     False  2012-05-30 14:39:50+00:00            415
# 365095        cino_1969     False  2012-05-16 11:27:04+00:00           1961
# 365096         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 365097         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
#
#         Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                2138              0       it  2022-08-31 15:04:03+00:00
# 1                4196            249       it  2022-08-31 14:43:58+00:00
# 2                9958              0       es  2022-08-31 12:53:16+00:00
# 3                9958              6       es  2022-08-31 12:51:54+00:00
# 4                 292              0      qme  2022-08-30 16:33:55+00:00
# ...               ...            ...      ...                        ...
# 365093           3213              0       it  2020-11-13 09:26:07+00:00
# 365094           1534              0       it  2020-11-13 09:19:49+00:00
# 365095           1837              0      qme  2020-11-13 09:00:48+00:00
# 365096           3213             27       it  2020-11-13 08:59:38+00:00
# 365097           3213             17       it  2020-11-13 08:57:07+00:00
#
#         Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 0                     0  Twitter for Android  1564992420714012672
# 1                   989      Twitter Web App  1564987364946186242
# 2                     1   Twitter for iPhone  1564959504386740225
# 3                    10   Twitter for iPhone  1564959162693558273
# 4                     0  Twitter for Android  1564652646505619460
# ...                 ...                  ...                  ...
# 365093                6      Twitter Web App  1327180935738109953
# 365094               12  Twitter for Android  1327179349016064002
# 365095                1  Twitter for Android  1327174565135593472
# 365096               75      Twitter Web App  1327174271328718851
# 365097               79      Twitter Web App  1327173639293300737
#
#                                                     Tweet  \
# 0       @maurobiani @repubblica Due cuori e una Campag...
# 1       #persone #migranti #salvini #meloni #CampagnaE...
# 2       Estas mil 93 denuncias contra menores de edad ...
# 3       En #México, al menos mil 93 niñas, niños y ado...
# 4       @bartolopietro1 @repubblica #migranti #impegno...
# ...                                                   ...
# 365093                      @gianlufratta la ringrazio...
# 365094  @SMaurizi Menomale che esistono ancora persone...
# 365095                  @SMaurizi https://t.co/JcygYTGuvi
# 365096  3. non potrò mai dimenticare #cablo come quest...
# 365097  2. ho passato gli ultimi 10 anni a leggere i f...
#
#                                                  Hashtags  \
# 0                      ['persone', 'migranti', 'Matrice']
# 1       ['persone', 'migranti', 'salvini', 'meloni', '...
# 2                                            ['migrante']
# 3                      ['México', 'víctimas', 'migrante']
# 4                    ['migranti', 'impegno', 'Lampedusa']
# ...                                                   ...
# 365093                                                NaN
# 365094                                                NaN
# 365095                                                NaN
# 365096                            ['cablo', 'GuerraIraq']
# 365097           ['Afghanistan', 'Iraq', 'cablo', 'Iraq']
#
#             Conversation_Id                     In_reply_To Coordinates Place
# 0       1564987364946186242                      maurobiani         NaN   NaN
# 1       1564987364946186242                             NaN         NaN   NaN
# 2       1564959162693558273                    EuniceRendon         NaN   NaN
# 3       1564959162693558273                             NaN         NaN   NaN
# 4       1564563868705329155                  bartolopietro1         NaN   NaN
# ...                     ...                             ...         ...   ...
# 365093  1327172894816940033  https://twitter.com/CosmolukaG         NaN   NaN
# 365094  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
# 365095  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
# 365096  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
# 365097  1327172894816940033    https://twitter.com/SMaurizi         NaN   NaN
#
# [365098 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365098 entries, 0 to 365097
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   User             365098 non-null  object
#  1   verified         365098 non-null  bool
#  2   Date_Created     365098 non-null  object
#  3   Follows_Count    365098 non-null  int64
#  4   Friends_Count    365098 non-null  int64
#  5   Retweet_Count    365098 non-null  int64
#  6   Language         365098 non-null  object
#  7   Date_Tweet       365098 non-null  object
#  8   Number_of_Likes  365098 non-null  int64
#  9   Source_of_Tweet  365098 non-null  object
#  10  Tweet_Id         365098 non-null  int64
#  11  Tweet            365098 non-null  object
#  12  Hashtags         40172 non-null   object
#  13  Conversation_Id  365098 non-null  int64
#  14  In_reply_To      358303 non-null  object
#  15  Coordinates      7215 non-null    object
#  16  Place            7215 non-null    object
# dtypes: bool(1), int64(6), object(10)
# memory usage: 44.9+ MB

# %%
df["In_reply_To"] = df["In_reply_To"].str.replace("https://twitter.com/", "")
# Out:
# C:\Users\lpall\AppData\Local\Temp\ipykernel_8876\3522921684.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["In_reply_To"] = df["In_reply_To"].str.replace("https://twitter.com/", "")

# %%
df.In_reply_To
# Out:
# 0             maurobiani
# 1                    NaN
# 2           EuniceRendon
# 3                    NaN
# 4         bartolopietro1
#                ...
# 365093        CosmolukaG
# 365094          SMaurizi
# 365095          SMaurizi
# 365096          SMaurizi
# 365097          SMaurizi
# Name: In_reply_To, Length: 365098, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365098 entries, 0 to 365097
# Data columns (total 17 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   User             365098 non-null  object
#  1   verified         365098 non-null  bool
#  2   Date_Created     365098 non-null  object
#  3   Follows_Count    365098 non-null  int64
#  4   Friends_Count    365098 non-null  int64
#  5   Retweet_Count    365098 non-null  int64
#  6   Language         365098 non-null  object
#  7   Date_Tweet       365098 non-null  object
#  8   Number_of_Likes  365098 non-null  int64
#  9   Source_of_Tweet  365098 non-null  object
#  10  Tweet_Id         365098 non-null  int64
#  11  Tweet            365098 non-null  object
#  12  Hashtags         40172 non-null   object
#  13  Conversation_Id  365098 non-null  int64
#  14  In_reply_To      358303 non-null  object
#  15  Coordinates      7215 non-null    object
#  16  Place            7215 non-null    object
# dtypes: bool(1), int64(6), object(10)
# memory usage: 44.9+ MB

# %%
df['User'].nunique()
# Out:
# 132464

# %%
df.groupby(['User', 'Tweet']).ngroups
# Out:
# 361167

# %% [markdown]
# Tengo tweet unici (per evitare spam)

# %%
df = df.drop_duplicates(['User', 'Tweet'])

# %%
df
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 0       DorAntifascista     False  2018-06-22 08:12:10+00:00           2074
# 1            maurobiani     False  2007-08-06 20:19:05+00:00          79692
# 2          EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 3          EuniceRendon      True  2010-04-25 20:25:43+00:00          30384
# 4             GerriLiu5     False  2018-08-28 21:10:41+00:00            353
# ...                 ...       ...                        ...            ...
# 365093         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 365094       CosmolukaG     False  2012-05-30 14:39:50+00:00            415
# 365095        cino_1969     False  2012-05-16 11:27:04+00:00           1961
# 365096         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 365097         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
#
#         Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                2138              0       it  2022-08-31 15:04:03+00:00
# 1                4196            249       it  2022-08-31 14:43:58+00:00
# 2                9958              0       es  2022-08-31 12:53:16+00:00
# 3                9958              6       es  2022-08-31 12:51:54+00:00
# 4                 292              0      qme  2022-08-30 16:33:55+00:00
# ...               ...            ...      ...                        ...
# 365093           3213              0       it  2020-11-13 09:26:07+00:00
# 365094           1534              0       it  2020-11-13 09:19:49+00:00
# 365095           1837              0      qme  2020-11-13 09:00:48+00:00
# 365096           3213             27       it  2020-11-13 08:59:38+00:00
# 365097           3213             17       it  2020-11-13 08:57:07+00:00
#
#         Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 0                     0  Twitter for Android  1564992420714012672
# 1                   989      Twitter Web App  1564987364946186242
# 2                     1   Twitter for iPhone  1564959504386740225
# 3                    10   Twitter for iPhone  1564959162693558273
# 4                     0  Twitter for Android  1564652646505619460
# ...                 ...                  ...                  ...
# 365093                6      Twitter Web App  1327180935738109953
# 365094               12  Twitter for Android  1327179349016064002
# 365095                1  Twitter for Android  1327174565135593472
# 365096               75      Twitter Web App  1327174271328718851
# 365097               79      Twitter Web App  1327173639293300737
#
#                                                     Tweet  \
# 0       @maurobiani @repubblica Due cuori e una Campag...
# 1       #persone #migranti #salvini #meloni #CampagnaE...
# 2       Estas mil 93 denuncias contra menores de edad ...
# 3       En #México, al menos mil 93 niñas, niños y ado...
# 4       @bartolopietro1 @repubblica #migranti #impegno...
# ...                                                   ...
# 365093                      @gianlufratta la ringrazio...
# 365094  @SMaurizi Menomale che esistono ancora persone...
# 365095                  @SMaurizi https://t.co/JcygYTGuvi
# 365096  3. non potrò mai dimenticare #cablo come quest...
# 365097  2. ho passato gli ultimi 10 anni a leggere i f...
#
#                                                  Hashtags  \
# 0                      ['persone', 'migranti', 'Matrice']
# 1       ['persone', 'migranti', 'salvini', 'meloni', '...
# 2                                            ['migrante']
# 3                      ['México', 'víctimas', 'migrante']
# 4                    ['migranti', 'impegno', 'Lampedusa']
# ...                                                   ...
# 365093                                                NaN
# 365094                                                NaN
# 365095                                                NaN
# 365096                            ['cablo', 'GuerraIraq']
# 365097           ['Afghanistan', 'Iraq', 'cablo', 'Iraq']
#
#             Conversation_Id     In_reply_To Coordinates Place
# 0       1564987364946186242      maurobiani         NaN   NaN
# 1       1564987364946186242             NaN         NaN   NaN
# 2       1564959162693558273    EuniceRendon         NaN   NaN
# 3       1564959162693558273             NaN         NaN   NaN
# 4       1564563868705329155  bartolopietro1         NaN   NaN
# ...                     ...             ...         ...   ...
# 365093  1327172894816940033      CosmolukaG         NaN   NaN
# 365094  1327172894816940033        SMaurizi         NaN   NaN
# 365095  1327172894816940033        SMaurizi         NaN   NaN
# 365096  1327172894816940033        SMaurizi         NaN   NaN
# 365097  1327172894816940033        SMaurizi         NaN   NaN
#
# [361167 rows x 17 columns]

# %% [markdown]
# Elimino tutti gli utenti che si rispondono da soli o che hanno scritto tweet in lingua non italiana

# %%
for i in df.index:
    if df['User'][i] == df['In_reply_To'][i] or df['Language'][i] != 'it':
        df = df.drop(labels=i, axis=0)

# %%
df
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 0       DorAntifascista     False  2018-06-22 08:12:10+00:00           2074
# 1            maurobiani     False  2007-08-06 20:19:05+00:00          79692
# 5        bartolopietro1      True  2016-09-25 12:42:38+00:00          29646
# 7            fratotolo2     False  2021-05-13 06:19:16+00:00          19710
# 8          brunieradino     False  2011-11-07 16:10:19+00:00            223
# ...                 ...       ...                        ...            ...
# 365088    JackieMilesiF     False  2011-01-01 22:36:03+00:00           2139
# 365089          GCDileo     False  2011-11-05 08:06:40+00:00            337
# 365092     microcerotis     False  2013-05-22 10:44:40+00:00            423
# 365093         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 365094       CosmolukaG     False  2012-05-30 14:39:50+00:00            415
#
#         Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                2138              0       it  2022-08-31 15:04:03+00:00
# 1                4196            249       it  2022-08-31 14:43:58+00:00
# 5                  61             45       it  2022-08-30 10:41:09+00:00
# 7                 233            144       it  2022-08-30 10:21:52+00:00
# 8                 276              0       it  2022-08-29 15:01:47+00:00
# ...               ...            ...      ...                        ...
# 365088           2896              0       it  2020-11-13 12:20:16+00:00
# 365089            415              1       it  2020-11-13 10:48:06+00:00
# 365092            291              0       it  2020-11-13 09:57:35+00:00
# 365093           3213              0       it  2020-11-13 09:26:07+00:00
# 365094           1534              0       it  2020-11-13 09:19:49+00:00
#
#         Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 0                     0  Twitter for Android  1564992420714012672
# 1                   989      Twitter Web App  1564987364946186242
# 5                   163      Twitter Web App  1564563868705329155
# 7                   337   Twitter for iPhone  1564559016759533569
# 8                     0   Twitter for iPhone  1564267073139838976
# ...                 ...                  ...                  ...
# 365088                0     Twitter for iPad  1327224759717941248
# 365089                7  Twitter for Android  1327201567515303937
# 365092                0      Twitter Web App  1327188854848282624
# 365093                6      Twitter Web App  1327180935738109953
# 365094               12  Twitter for Android  1327179349016064002
#
#                                                     Tweet  \
# 0       @maurobiani @repubblica Due cuori e una Campag...
# 1       #persone #migranti #salvini #meloni #CampagnaE...
# 5       Bravo Angelo e complimenti a @Repubblica per a...
# 7       Dal primo gennaio al 29 agosto, gli sbarchi di...
# 8       @fratotolo2 👉 non aiutandoli e non consentendo...
# ...                                                   ...
# 365088  @SMaurizi Ho letto una parte dei cables che ha...
# 365089  @SMaurizi Grazie, considerando anche che la no...
# 365092  @SMaurizi PUBLIC LIBRARY OF US DIPLOMACY\nhttp...
# 365093                      @gianlufratta la ringrazio...
# 365094  @SMaurizi Menomale che esistono ancora persone...
#
#                                                  Hashtags  \
# 0                      ['persone', 'migranti', 'Matrice']
# 1       ['persone', 'migranti', 'salvini', 'meloni', '...
# 5                    ['migranti', 'impegno', 'Lampedusa']
# 7                                            ['migranti']
# 8                                            ['migranti']
# ...                                                   ...
# 365088                                                NaN
# 365089                                                NaN
# 365092                                                NaN
# 365093                                                NaN
# 365094                                                NaN
#
#             Conversation_Id In_reply_To Coordinates Place
# 0       1564987364946186242  maurobiani         NaN   NaN
# 1       1564987364946186242         NaN         NaN   NaN
# 5       1564563868705329155         NaN         NaN   NaN
# 7       1564559016759533569         NaN         NaN   NaN
# 8       1563958254744518656  fratotolo2         NaN   NaN
# ...                     ...         ...         ...   ...
# 365088  1327172894816940033    SMaurizi         NaN   NaN
# 365089  1327172894816940033    SMaurizi         NaN   NaN
# 365092  1327172894816940033    SMaurizi         NaN   NaN
# 365093  1327172894816940033  CosmolukaG         NaN   NaN
# 365094  1327172894816940033    SMaurizi         NaN   NaN
#
# [138543 rows x 17 columns]

# %%
df.reset_index(inplace=True)
del(df['index'])
df
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 0       DorAntifascista     False  2018-06-22 08:12:10+00:00           2074
# 1            maurobiani     False  2007-08-06 20:19:05+00:00          79692
# 2        bartolopietro1      True  2016-09-25 12:42:38+00:00          29646
# 3            fratotolo2     False  2021-05-13 06:19:16+00:00          19710
# 4          brunieradino     False  2011-11-07 16:10:19+00:00            223
# ...                 ...       ...                        ...            ...
# 138538    JackieMilesiF     False  2011-01-01 22:36:03+00:00           2139
# 138539          GCDileo     False  2011-11-05 08:06:40+00:00            337
# 138540     microcerotis     False  2013-05-22 10:44:40+00:00            423
# 138541         SMaurizi     False  2011-09-06 13:16:27+00:00          50018
# 138542       CosmolukaG     False  2012-05-30 14:39:50+00:00            415
#
#         Friends_Count  Retweet_Count Language                 Date_Tweet  \
# 0                2138              0       it  2022-08-31 15:04:03+00:00
# 1                4196            249       it  2022-08-31 14:43:58+00:00
# 2                  61             45       it  2022-08-30 10:41:09+00:00
# 3                 233            144       it  2022-08-30 10:21:52+00:00
# 4                 276              0       it  2022-08-29 15:01:47+00:00
# ...               ...            ...      ...                        ...
# 138538           2896              0       it  2020-11-13 12:20:16+00:00
# 138539            415              1       it  2020-11-13 10:48:06+00:00
# 138540            291              0       it  2020-11-13 09:57:35+00:00
# 138541           3213              0       it  2020-11-13 09:26:07+00:00
# 138542           1534              0       it  2020-11-13 09:19:49+00:00
#
#         Number_of_Likes      Source_of_Tweet             Tweet_Id  \
# 0                     0  Twitter for Android  1564992420714012672
# 1                   989      Twitter Web App  1564987364946186242
# 2                   163      Twitter Web App  1564563868705329155
# 3                   337   Twitter for iPhone  1564559016759533569
# 4                     0   Twitter for iPhone  1564267073139838976
# ...                 ...                  ...                  ...
# 138538                0     Twitter for iPad  1327224759717941248
# 138539                7  Twitter for Android  1327201567515303937
# 138540                0      Twitter Web App  1327188854848282624
# 138541                6      Twitter Web App  1327180935738109953
# 138542               12  Twitter for Android  1327179349016064002
#
#                                                     Tweet  \
# 0       @maurobiani @repubblica Due cuori e una Campag...
# 1       #persone #migranti #salvini #meloni #CampagnaE...
# 2       Bravo Angelo e complimenti a @Repubblica per a...
# 3       Dal primo gennaio al 29 agosto, gli sbarchi di...
# 4       @fratotolo2 👉 non aiutandoli e non consentendo...
# ...                                                   ...
# 138538  @SMaurizi Ho letto una parte dei cables che ha...
# 138539  @SMaurizi Grazie, considerando anche che la no...
# 138540  @SMaurizi PUBLIC LIBRARY OF US DIPLOMACY\nhttp...
# 138541                      @gianlufratta la ringrazio...
# 138542  @SMaurizi Menomale che esistono ancora persone...
#
#                                                  Hashtags  \
# 0                      ['persone', 'migranti', 'Matrice']
# 1       ['persone', 'migranti', 'salvini', 'meloni', '...
# 2                    ['migranti', 'impegno', 'Lampedusa']
# 3                                            ['migranti']
# 4                                            ['migranti']
# ...                                                   ...
# 138538                                                NaN
# 138539                                                NaN
# 138540                                                NaN
# 138541                                                NaN
# 138542                                                NaN
#
#             Conversation_Id In_reply_To Coordinates Place
# 0       1564987364946186242  maurobiani         NaN   NaN
# 1       1564987364946186242         NaN         NaN   NaN
# 2       1564563868705329155         NaN         NaN   NaN
# 3       1564559016759533569         NaN         NaN   NaN
# 4       1563958254744518656  fratotolo2         NaN   NaN
# ...                     ...         ...         ...   ...
# 138538  1327172894816940033    SMaurizi         NaN   NaN
# 138539  1327172894816940033    SMaurizi         NaN   NaN
# 138540  1327172894816940033    SMaurizi         NaN   NaN
# 138541  1327172894816940033  CosmolukaG         NaN   NaN
# 138542  1327172894816940033    SMaurizi         NaN   NaN
#
# [138543 rows x 17 columns]

# %%
df['User'].nunique()
# Out:
# 48262

# %%
df
# Out:
#                    User  verified               Date_Created  Follows_Count  \
# 0           nitewriter3     False  2022-07-14 23:47:29+00:00              2
# 1       Christi09341475     False  2021-12-24 13:52:34+00:00              6
# 2         Blank40195976     False  2016-06-04 22:27:20+00:00              6
# 3         Blank40195976     False  2016-06-04 22:27:20+00:00              6
# 4              ragge002     False  2022-05-12 09:59:04+00:00              1
# ...                 ...       ...                        ...            ...
# 137409    adanmartinezt     False  2010-08-22 04:05:08+00:00           2214
# 137410       MennyValdz     False  2010-05-23 20:12:28+00:00          33235
# 137411       papapirupo     False  2011-03-31 04:03:57+00:00           7057
# 137412          2OSITOO     False  2012-07-02 01:28:20+00:00          13142
# 137413        JoeRooms1     False  2019-03-19 06:28:50+00:00            380
#
#         Friends_Count  Retweet_Count Language  Number_of_Likes  \
# 0                  20              0       it                0
# 1                  31              0       it                1
# 2                  29              0       it                0
# 3                  29              0       it                0
# 4                  45              0       it                0
# ...               ...            ...      ...              ...
# 137409           3263              0       it                1
# 137410           1660              0       it                0
# 137411           5370              0       it                0
# 137412          12887              0       it                0
# 137413            618              0       it                1
#
#             Source_of_Tweet             Tweet_Id  \
# 0       Twitter for Android  1571699213720846337
# 1        Twitter for iPhone  1571145153695588353
# 2       Twitter for Android  1570683600823287808
# 3       Twitter for Android  1570683119333961729
# 4       Twitter for Android  1570697404068036609
# ...                     ...                  ...
# 137409  Twitter for Android  1189617141235867648
# 137410   Twitter Web Client  1184634515467182080
# 137411  Twitter for Android  1184477975800156160
# 137412      Twitter Web App  1178776764476248064
# 137413   Twitter for iPhone  1175548503919079425
#
#                                                     Tweet Hashtags  \
# 0       @GiorgiaMeloni @FratellidItalia Chi  permette ...      NaN
# 1       @GiorgiaMeloni @FratellidItalia No assolutamen...      NaN
# 2       @ragge002 @eleloverre @matteosalvinimi Immigra...      NaN
# 3       @ragge002 @eleloverre @matteosalvinimi Le cart...      NaN
# 4       @Blank40195976 @eleloverre @matteosalvinimi Il...      NaN
# ...                                                   ...      ...
# 137409  @Ernesto81658761 @juanchitotopo @DonPedorrino ...      NaN
# 137410  @AnibalMSilvaMx @cecyvogel @MISTER_OPTIMUS @Os...      NaN
# 137411  @M1M0Sapiens @MISTER_OPTIMUS @OscarVaj47 @ElMe...      NaN
# 137412  @juanchitotopo @Lic_IsmaelPena @OscarVaj47 @es...      NaN
# 137413  @papapirupo @RencorMiMo @MISTER_OPTIMUS @Oscar...      NaN
#
#             Conversation_Id     In_reply_To Coordinates Place  Data_Tweet  \
# 0       1538924006878887936   GiorgiaMeloni         NaN   NaN  2022-09-19
# 1       1538924006878887936   GiorgiaMeloni         NaN   NaN  2022-09-17
# 2       1563955335303421953        ragge002         NaN   NaN  2022-09-16
# 3       1563955335303421953        ragge002         NaN   NaN  2022-09-16
# 4       1563955335303421953   Blank40195976         NaN   NaN  2022-09-16
# ...                     ...             ...         ...   ...         ...
# 137409  1145123250554511362             NaN         NaN   NaN  2019-10-30
# 137410  1145123250554511362  AnibalMSilvaMx         NaN   NaN  2019-10-17
# 137411  1145123250554511362     M1M0Sapiens         NaN   NaN  2019-10-16
# 137412  1145123250554511362             NaN         NaN   NaN  2019-09-30
# 137413  1145123250554511362      papapirupo         NaN   NaN  2019-09-21
#
#         Month  Year Year_Month
# 0           9  2022     2022-9
# 1           9  2022     2022-9
# 2           9  2022     2022-9
# 3           9  2022     2022-9
# 4           9  2022     2022-9
# ...       ...   ...        ...
# 137409     10  2019    2019-10
# 137410     10  2019    2019-10
# 137411     10  2019    2019-10
# 137412      9  2019     2019-9
# 137413      9  2019     2019-9
#
# [137414 rows x 20 columns]

# %%
#df.to_csv("df.csv", sep=",", index=False)
